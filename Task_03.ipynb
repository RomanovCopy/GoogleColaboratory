# %% [markdown]
# <a href="https://colab.research.google.com/github/RomanovCopy/GoogleColaboratory/blob/master/Task_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sas
df=pd.read_csv('https://minobrnauki.gov.ru/upload/iblock/78d/78d77b235f7b3b14e1ac671e61435311.csv', sep=';' , encoding='cp1251')
df1=df[df['Численность студентов заочная форма, человек, 2019']>10000]
msk=df1['Субъект РФ'].str.contains('округ')
regions=df1.drop(df1[msk].index)
regions=regions.drop(regions[regions['Субъект РФ'].str.contains('Федерация')].index)
plot = sas.barplot(regions, x ='Субъект РФ', y ='Численность студентов заочная форма, человек, 2019')
plot.set_xticklabels(labels=regions['Субъект РФ'], rotation=90)
# Out:
# [Text(0, 0, '   Белгородская область'),
#  Text(1, 0, '   Брянская область'),
#  Text(2, 0, '   Владимирская область'),
#  Text(3, 0, '   Воронежская область'),
#  Text(4, 0, '   Курская область'),
#  Text(5, 0, '   Московская область'),
#  Text(6, 0, '   Орловская область'),
#  Text(7, 0, '   Рязанская область'),
#  Text(8, 0, '   Тамбовская область'),
#  Text(9, 0, '   Тульская область'),
#  Text(10, 0, '   Ярославская область'),
#  Text(11, 0, '   г.Москва'),
#  Text(12, 0, '   г.Санкт-Петербург'),
#  Text(13, 0, '   Краснодарский край'),
#  Text(14, 0, '   Астраханская область'),
#  Text(15, 0, '   Волгоградская область'),
#  Text(16, 0, '   Ростовская область'),
#  Text(17, 0, '   Республика Крым'),
#  Text(18, 0, '   Республика Дагестан'),
#  Text(19, 0, '   Чеченская Республика'),
#  Text(20, 0, '   Ставропольский край'),
#  Text(21, 0, '   Республика Башкортостан'),
#  Text(22, 0, '   Республика Татарстан'),
#  Text(23, 0, '   Удмуртская Республика'),
#  Text(24, 0, '   Чувашская Республика'),
#  Text(25, 0, '   Пермский край'),
#  Text(26, 0, '   Кировская область'),
#  Text(27, 0, '   Нижегородская область'),
#  Text(28, 0, '   Оренбургская область'),
#  Text(29, 0, '   Пензенская область'),
#  Text(30, 0, '   Самарская область'),
#  Text(31, 0, '   Саратовская область'),
#  Text(32, 0, '   Ульяновская область'),
#  Text(33, 0, '   Свердловская область'),
#  Text(34, 0, '   Тюменская область'),
#  Text(35, 0, '   Челябинская область'),
#  Text(36, 0, '   Алтайский край'),
#  Text(37, 0, '   Красноярский край'),
#  Text(38, 0, '   Иркутская область'),
#  Text(39, 0, '   Кемеровская область'),
#  Text(40, 0, '   Новосибирская область'),
#  Text(41, 0, '   Омская область'),
#  Text(42, 0, '   Томская область'),
#  Text(43, 0, '   Забайкальский край'),
#  Text(44, 0, '   Приморский край'),
#  Text(45, 0, '   Хабаровский край')]
